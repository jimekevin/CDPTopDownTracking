# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import mayavi
# %matplotlib inline

# %%
def imshow(img):
    plt.figure(figsize = (10,10))
    plt.imshow(img, interpolation='nearest')
    plt.axis('off')
    plt.show()

# %%
imgs = [
    "../data/1622821073.png", #0
    "../data/1622821834.png", #1
    "../data/1623405106.png", #2
    "../data/1623409367.png", #3
    "../data/1623421460.png", #4
    "../data/1623508062.png"  #5
]
activeImg = imgs[5]

greyMat = cv.imread(cv.samples.findFile(activeImg))
if greyMat is None:
    sys.exit("Could not read the image.")
imshow(greyMat)

# %%
blurMat = cv.GaussianBlur(greyMat, (5, 5), 0)
imshow(blurMat)

# %%
prop_threshold = 0.6
prop_threshold_max = 255.0
ret, threshMat = cv.threshold(blurMat, prop_threshold * 255.0, prop_threshold_max, cv.THRESH_BINARY);
imshow(threshMat)

# %%
prop_morph_kernel = 23
morphKernel = cv.getStructuringElement(cv.MORPH_RECT, (prop_morph_kernel, prop_morph_kernel), (-1, -1));
morphMat = cv.morphologyEx(threshMat, cv.MORPH_OPEN, morphKernel);
morphMat = cv.morphologyEx(morphMat, cv.MORPH_CLOSE, morphKernel);
imshow(morphMat)

# %%
morphMat2 = morphMat.copy()

min_area = 25 * 25
max_area = 300 * 300

# Add white border to isolate contours from border
h, w, _ = morphMat2.shape
cv.rectangle(morphMat2, (0, 0), (w, h), (255,255,255), 100)

morphMat2 = cv.cvtColor(morphMat2, cv.COLOR_BGR2GRAY)
contours, hierarchy = cv.findContours(morphMat2, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

outMat = greyMat.copy()

for i, c in enumerate(contours):
    area = cv.contourArea(c)
    discarded = True
    if area > min_area and area < max_area:
        cv.drawContours(outMat, [contours[1]], -1, (255,0,0), 3)
        discarded = False
    discardedStr = '(discarded)' if discarded else ''
    print(f'{i}: {area} {discardedStr}')
imshow(outMat)
# Out:
# 0: 919601.0 (discarded)
# 1: 19598.5

# %%
cnt = contours[1]
outMat2 = outMat.copy()

rect = cv.minAreaRect(cnt)
box = cv.boxPoints(rect) # cv2.boxPoints(rect) for OpenCV 3.x
box = np.int0(box)
cv.drawContours(outMat2,[box],0,(0,0,255),2)
imshow(outMat2)

# %%
box2 = box
outMat3 = outMat2.copy()

sls = [ # sideLengths
    [0, np.linalg.norm(box2[0] - box2[1]), box2[0], box2[1], box2[2], box2[3]],
    [1, np.linalg.norm(box2[1] - box2[2]), box2[1], box2[2], box2[3], box2[0]],
    [2, np.linalg.norm(box2[2] - box2[3]), box2[2], box2[3], box2[0], box2[1]],
    [3, np.linalg.norm(box2[3] - box2[0]), box2[3], box2[0], box2[1], box2[2]],
]
sls = sorted(sls, key=lambda p: p[1])

rects = []
for i in range(2):
    _, length, x1, x2, x3, x4 = sls[i]
    v = x3 - x2 # direction
    v_hat = v / np.linalg.norm(v) # unit vector
    x3_new = x2 + (v_hat * length)
    x4_new = x1 + (v_hat * length)
    rect = np.int0([x1, x2, x3_new, x4_new])
    center = np.int0(x1 + ((x3_new - x1) / 2))
    rects.append([rect, center, False])

h, w, _ = outMat3.shape
img_center = np.int0([w / 2, h / 2])
r1, r2 = rects
dist2center1 = np.linalg.norm(img_center - r1[1])
dist2center2 = np.linalg.norm(img_center - r2[1])
dist2vertEdge1 = np.min([r1[1][0], w - r1[1][0]])
dist2vertEdge2 = np.min([r2[1][0], w - r2[1][0]])
dist2horizEdge1 = np.min([r1[1][1], h - r1[1][1]])
dist2horizEdge2 = np.min([r2[1][1], h - r2[1][1]])

maxCenterDist = img_center
maxVertDist = img_center[0]
maxHorizDist = img_center[1]

score1 = dist2center1 + (img_center[0] - dist2vertEdge1) + (img_center[1] - dist2horizEdge1)
score2 = dist2center2 + (img_center[0] - dist2vertEdge2) + (img_center[1] - dist2horizEdge2)
if score1 < score2:
    rects[0][2] = True
else:
    rects[1][2] = True

for i in range(2):
    color = (255,255,0) if rects[i][2] else (0, 0, 255)
    cv.drawContours(outMat3, [rects[i][0]], 0, color, 3) # draw box
    cv.circle(outMat3, tuple(rects[i][1]), 5, color, -1) # draw center
    
imshow(outMat3)

# %%
outMat4 = outMat3.copy()

activeRect = rects[0][0] if rects[0][2] else rects[1][0]

def shoelace(points): # area of triangle
    [x1,y1],[x2,y2],[x3,y3] = points
    return 0.5 * (((x2 - x1) * (y3 - y1)) - ((x3 - x1) * (y2 - y1)))
def pointInsideRotatedRect(p, rotatedRect):
    rp1, rp2, rp3, rp4 = rotatedRect
    area12p = shoelace([rp1, rp2, p])
    area23p = shoelace([rp2, rp3, p])
    area34p = shoelace([rp3, rp4, p])
    area41p = shoelace([rp4, rp1, p])
    areaPSum = area12p + area23p + area34p + area41p
    areaSum = shoelace([rp1, rp2, rp3]) + shoelace([rp1, rp4, rp3])
    return areaPSum <= areaSum

cnt = contours[1]
print([[c, pointInsideRotatedRect(c[0], activeRect)] for c in cnt])

imshow(outMat4)
# Out:
# [[[array([962,  51], dtype=int32)], False], [[array([963,  50], dtype=int32)], False], [[array([1086,   50], dtype=int32)], False], [[array([1087,   51], dtype=int32)], False], [[array([1087,   55], dtype=int32)], False], [[array([1079,   63], dtype=int32)], False], [[array([1078,   63], dtype=int32)], False], [[array([1076,   65], dtype=int32)], False], [[array([1075,   65], dtype=int32)], False], [[array([1073,   67], dtype=int32)], False], [[array([1072,   67], dtype=int32)], False], [[array([1069,   70], dtype=int32)], False], [[array([1068,   70], dtype=int32)], False], [[array([1067,   71], dtype=int32)], False], [[array([1066,   71], dtype=int32)], False], [[array([1063,   74], dtype=int32)], False], [[array([1062,   74], dtype=int32)], False], [[array([1061,   75], dtype=int32)], False], [[array([1060,   75], dtype=int32)], False], [[array([1058,   77], dtype=int32)], False], [[array([1056,   77], dtype=int32)], False], [[array([1049,   84], dtype=int32)], False], [[array([1048,   84], dtype=int32)], False], [[array([1047,   85], dtype=int32)], False], [[array([1046,   85], dtype=int32)], False], [[array([1045,   86], dtype=int32)], False], [[array([1044,   86], dtype=int32)], False], [[array([1041,   89], dtype=int32)], False], [[array([1040,   89], dtype=int32)], False], [[array([1039,   90], dtype=int32)], False], [[array([1038,   90], dtype=int32)], False], [[array([1034,   94], dtype=int32)], False], [[array([1033,   94], dtype=int32)], False], [[array([1032,   95], dtype=int32)], False], [[array([1032,   97], dtype=int32)], False], [[array([1026,  103], dtype=int32)], False], [[array([1025,  103], dtype=int32)], False], [[array([1023,  105], dtype=int32)], False], [[array([1023,  107], dtype=int32)], False], [[array([1022,  108], dtype=int32)], False], [[array([1022,  109], dtype=int32)], False], [[array([1021,  110], dtype=int32)], False], [[array([1021,  112], dtype=int32)], False], [[array([1020,  113], dtype=int32)], False], [[array([1020,  115], dtype=int32)], False], [[array([1019,  116], dtype=int32)], False], [[array([1015,  116], dtype=int32)], False], [[array([1015,  120], dtype=int32)], False], [[array([1014,  121], dtype=int32)], False], [[array([1014,  126], dtype=int32)], False], [[array([1013,  127], dtype=int32)], False], [[array([1013,  130], dtype=int32)], False], [[array([1012,  131], dtype=int32)], False], [[array([1012,  145], dtype=int32)], False], [[array([1011,  146], dtype=int32)], False], [[array([1011,  150], dtype=int32)], False], [[array([1010,  151], dtype=int32)], False], [[array([1010,  158], dtype=int32)], False], [[array([1009,  159], dtype=int32)], False], [[array([1009,  161], dtype=int32)], False], [[array([1008,  162], dtype=int32)], False], [[array([1008,  176], dtype=int32)], False], [[array([1006,  178], dtype=int32)], False], [[array([1006,  181], dtype=int32)], False], [[array([1003,  184], dtype=int32)], False], [[array([999, 184], dtype=int32)], False], [[array([999, 206], dtype=int32)], False], [[array([1000,  207], dtype=int32)], False], [[array([1000,  229], dtype=int32)], False], [[array([999, 230], dtype=int32)], False], [[array([999, 234], dtype=int32)], False], [[array([998, 235], dtype=int32)], False], [[array([998, 242], dtype=int32)], False], [[array([996, 244], dtype=int32)], False], [[array([996, 245], dtype=int32)], False], [[array([995, 246], dtype=int32)], False], [[array([995, 283], dtype=int32)], False], [[array([996, 284], dtype=int32)], False], [[array([996, 310], dtype=int32)], False], [[array([995, 311], dtype=int32)], False], [[array([995, 313], dtype=int32)], False], [[array([993, 315], dtype=int32)], False], [[array([993, 316], dtype=int32)], False], [[array([991, 318], dtype=int32)], False], [[array([991, 319], dtype=int32)], False], [[array([989, 321], dtype=int32)], False], [[array([989, 322], dtype=int32)], False], [[array([988, 323], dtype=int32)], False], [[array([988, 324], dtype=int32)], False], [[array([986, 326], dtype=int32)], False], ...
